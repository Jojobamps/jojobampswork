# %% [markdown]
# ### **JOSEPH BAMPOE**
#
# ### **11068675**
#
# ### **BMEN**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('red_wine.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.shape
# Out:
# (1599, 12)

# %%
dataset.ndim
# Out:
# 2

# %%
np.vstack(dataset)
# Out:
# array([['fixed acidity'],
#        ['volatile acidity'],
#        ['citric acid'],
#        ['residual sugar'],
#        ['chlorides'],
#        ['free sulfur dioxide'],
#        ['total sulfur dioxide'],
#        ['density'],
#        ['pH'],
#        ['sulphates'],
#        ['alcohol'],
#        ['quality']], dtype='<U20')

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          0
# chlorides               4
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1590, dtype: bool

# %%
dataset.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1590 non-null   float64
#  1   volatile acidity      1590 non-null   float64
#  2   citric acid           1590 non-null   float64
#  3   residual sugar        1590 non-null   float64
#  4   chlorides             1590 non-null   float64
#  5   free sulfur dioxide   1590 non-null   float64
#  6   total sulfur dioxide  1590 non-null   float64
#  7   density               1590 non-null   float64
#  8   pH                    1590 non-null   float64
#  9   sulphates             1590 non-null   float64
#  10  alcohol               1590 non-null   float64
#  11  quality               1590 non-null   float64
# dtypes: float64(12)
# memory usage: 161.5 KB

# %%
dataset.shape
# Out:
# (1590, 12)

# %%
columns_to_plot = [ 'citric acid' , 'quality']
plt.figure(figsize= (10,6))
for column in columns_to_plot:
    plt.hist(dataset[column], bins=30, alpha=0.5,label=column)
    plt.title(' citric acid vs. quality')
    plt.xlabel('citric acid')
    plt.ylabel('quality')
    plt.legend(loc='upper right')
    plt.show()

# %%
columns_to_plot = [ 'alcohol' , 'quality']
plt.figure(figsize= (10,6))
for column in columns_to_plot:
    plt.hist(dataset[column], bins=30, alpha=0.5,label=column)
    plt.title('Histogram of alcohol against quality')
    plt.xlabel('alcohol')
    plt.ylabel('quality')
    plt.legend(loc='upper right')
    plt.show()

# %%
avg_pH_by_quality = dataset.groupby('quality')['pH'].mean()
plt.figure(figsize=(8, 6))
avg_pH_by_quality.plot(kind='bar', color='skyblue')
plt.title('Average pH by Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Average pH')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(dataset['density'], dataset['fixed acidity'], color='green', alpha=0.5)
plt.title('density vs. fixed acidity')
plt.xlabel('Density ')
plt.ylabel('Fixed Acidity')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **A REPORT ON ALL PLOTS AND GRAPHS OBTAINED**
# ---
# #### **Histogram of Citric acid vs quality**
# ##### The histogram displays the distribution of wine quality rating in the red wine based on the citric acid content of the red wine dataset.The x-axis represents the range for citric acid content, while the y-axis indicates the frequency of wines falling within each citric acid content range for various quality levels.The histogram helps us observe how citric acid content is distributed among different quality ratings, and also whether or not quality ratings tend to have higher or lower citric acid content.
#
# #### **Histogram of alcohol against quality**
# ##### The histogram displays the distribution of the quality of red wine based on its alcohol content.The x-axis represents range of alcohol percentage present in the dataset and the y-axis represents the number of occurrences for each range of alcohol content within specific quality ratings.The histogram shows how certain quality levels are concentrated within specific alcohol ranges.
#
# #### **A bar chart of pH vs. quality**
# ##### The bar chart plotted illustrates the pH level of each wine quality rating present in the red wine dataset. Each bar represents the mean pH value corresponding to a specific wine quality level. The x-axis represents the quality and the y-axis represents the average pH of red wine.The title of this graph is Average pH by Wine Quality.
#
#
# #### **A scatter plot density vs. fixed acidity**
# ##### The scatter plot illustrates the relationship between the density and fixed acidity of wines in the dataset.The x-axis represents the fixed acidity values and the y-axis represents the densityy values.The scatter plot shows a strong correlation between the two variables because of the noticeable trend where an increase or decrease in fixed acidity corresponds to a similar trend in density.
#
# ##### In conclusion, the visual exploration of the red wine dataset through various plots and graphs has provided valuable insight into relationships among differnt characteristics.
